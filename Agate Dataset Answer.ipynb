# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib notebook
import seaborn as sns

# %%
df1 = pd.read_csv('KPI-2017.csv')
df2 = pd.read_csv('KPI-2018.csv')
df_all = pd.read_csv('KPI-All.csv')

# %%
df1
# Out:
#      Month  New_User    DAU  D1_Ret (%)  D7_Ret (%)  D30_Ret (%)  Avg_Session  \
# 0   Jan-17    160402  20389       35.92        7.95         2.24            5
# 1   Feb-17    110829  17035       34.82        8.26         2.36            5
# 2   Mar-17    116097  15639       34.87        7.71         1.61            4
# 3   Apr-17    101066  14716       34.84        8.48         1.90            4
# 4   May-17    119965  15510       34.72        7.87         2.05            5
# 5   Jun-17     94217  14645       34.84        7.11         1.70            5
# 6   Jul-17     69633  10370       32.74        6.73         1.40            5
# 7   Aug-17     47090   7361       32.07        6.66         1.35            4
# 8   Sep-17     35245   5881       30.53        5.68         1.34            3
# 9   Oct-17     33472   5001       30.89        5.81         1.51            4
# 10  Nov-17     31808   4661       31.38        5.81         1.49            4
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Month                  12 non-null     object
#  1   New_User               12 non-null     int64
#  2   DAU                    12 non-null     int64
#  3   D1_Ret (%)             12 non-null     float64
#  4   D7_Ret (%)             12 non-null     float64
#  5   D30_Ret (%)            12 non-null     float64
#  6   Avg_Session            12 non-null     int64
#  7   Playtime/Day (minute)  12 non-null     int64
#  8   Paying_User            12 non-null     int64
#  9   Gross_Rev              12 non-null     float64
#  10  ARPPU                  12 non-null     float64
#  11  ARPDAU                 12 non-null     float64
#  12  Conv_Rate (%)          12 non-null     float64
# dtypes: float64(7), int64(5), object(1)
# memory usage: 1.3+ KB

# %%
df1.corr()
# Out:
#                        New_User       DAU  D1_Ret (%)  D7_Ret (%)  \
# New_User               1.000000  0.988062    0.956816    0.902984
# DAU                    0.988062  1.000000    0.969948    0.927767
# D1_Ret (%)             0.956816  0.969948    1.000000    0.944879
# D7_Ret (%)             0.902984  0.927767    0.944879    1.000000
# D30_Ret (%)            0.780977  0.786806    0.836851    0.811400
# Avg_Session            0.714597  0.729769    0.771551    0.667811
# Playtime/Day (minute)  0.793666  0.775290    0.712861    0.658625
# Paying_User            0.859246  0.910750    0.902413    0.825929
# Gross_Rev              0.986756  0.973203    0.928760    0.857786
# ARPPU                 -0.367951 -0.437526   -0.445706   -0.461845
# ARPDAU                 0.020368 -0.036554   -0.112760   -0.195707
# Conv_Rate (%)          0.087614  0.189362    0.166852    0.110601
#
#                        D30_Ret (%)  Avg_Session  Playtime/Day (minute)  \
# ...

# %%
ax = sns.heatmap(df1.corr(), annot=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df2.corr()
# Out:
#                        New_User       DAU  D1_Ret (%)  D7_Ret (%)  \
# New_User               1.000000  0.881476    0.546701   -0.219091
# DAU                    0.881476  1.000000    0.500725   -0.136101
# D1_Ret (%)             0.546701  0.500725    1.000000   -0.003285
# D7_Ret (%)            -0.219091 -0.136101   -0.003285    1.000000
# D30_Ret (%)           -0.392154 -0.214903   -0.403562    0.282165
# Avg_Session           -0.035734  0.083318    0.176514   -0.072711
# Playtime/Day (minute) -0.123789 -0.029502   -0.307377   -0.211177
# Paying_User           -0.257686  0.167239   -0.075392    0.479627
# Gross_Rev              0.621419  0.839717    0.414051    0.029479
# ARPPU                  0.846448  0.625988    0.458356   -0.449109
# ARPDAU                -0.400287 -0.227383   -0.068203    0.466982
# Conv_Rate (%)         -0.795417 -0.436676   -0.449825    0.375108
#
#                        D30_Ret (%)  Avg_Session  Playtime/Day (minute)  \
# ...

# %%
bx = sns.heatmap(df2.corr(), annot=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df_all.corr()
# Out:
#                        New_User       DAU  D1_Ret (%)  D7_Ret (%)  \
# New_User               1.000000  0.986616    0.893983    0.922666
# DAU                    0.986616  1.000000    0.865260    0.948168
# D1_Ret (%)             0.893983  0.865260    1.000000    0.840833
# D7_Ret (%)             0.922666  0.948168    0.840833    1.000000
# D30_Ret (%)            0.765233  0.769625    0.744360    0.800775
# Avg_Session            0.758460  0.803154    0.639234    0.758159
# Playtime/Day (minute)  0.845402  0.864251    0.643305    0.792117
# Paying_User            0.914588  0.952793    0.830414    0.904095
# Gross_Rev              0.984764  0.986689    0.843853    0.917999
# ARPPU                 -0.311066 -0.392292   -0.264376   -0.484819
# ARPDAU                 0.327494  0.347876    0.112343    0.284713
# Conv_Rate (%)          0.476837  0.592127    0.315212    0.575687
#
#                        D30_Ret (%)  Avg_Session  Playtime/Day (minute)  \
# ...

# %%
cx = sns.heatmap(df_all.corr(), annot=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df1.describe().T
# Out:
#                        count          mean           std       min  \
# New_User                12.0  78104.750000  45240.172418  17433.00
# DAU                     12.0  11230.000000   5755.486363   3552.00
# D1_Ret (%)              12.0     33.064167      2.214586     29.15
# D7_Ret (%)              12.0      6.938333      1.126021      5.19
# D30_Ret (%)             12.0      1.588333      0.579856      0.11
# Avg_Session             12.0      4.250000      0.753778      3.00
# Playtime/Day (minute)   12.0     12.750000      1.764550     10.00
# Paying_User             12.0    439.833333    284.687654    102.00
# Gross_Rev               12.0    908.859167    507.861227    368.48
# ARPPU                   12.0      2.405000      0.908640      1.29
# ARPDAU                  12.0      0.080833      0.015050      0.06
# Conv_Rate (%)           12.0      0.555833      0.164618      0.32
#
#                               25%       50%          75%        max
# ...

# %%
df2.describe().T
# Out:
#                        count          mean          std       min       25%  \
# New_User                13.0  24272.153846  7361.431313  18151.00  19095.00
# DAU                     13.0   2831.153846   631.635291   2106.00   2357.00
# D1_Ret (%)              13.0     31.761538     0.716890     30.59     31.26
# D7_Ret (%)              13.0      5.396923     0.256170      5.04      5.20
# D30_Ret (%)             13.0      1.163077     0.216078      0.82      1.05
# Avg_Session             13.0      2.615385     0.650444      2.00      2.00
# Playtime/Day (minute)   13.0      9.923077     0.759555      9.00      9.00
# Paying_User             13.0     65.153846    17.319768     39.00     54.00
# Gross_Rev               13.0    192.312308    44.927669    138.51    152.96
# ARPPU                   13.0      3.109231     1.075658      2.04      2.63
# ARPDAU                  13.0      0.067692     0.007250      0.05      0.07
# ...

# %%
df_all.describe().T
# Out:
#                        count        mean           std       min       25%  \
# New_User                25.0  50111.8000  41456.247683  17433.00  20228.00
# DAU                     25.0   6862.6000   5807.117981   2106.00   2642.00
# D1_Ret (%)              25.0     32.3868      1.716388     29.15     31.26
# D7_Ret (%)              25.0      6.1368      1.109815      5.04      5.35
# D30_Ret (%)             25.0      1.3672      0.473784      0.11      1.19
# Avg_Session             25.0      3.4000      1.080123      2.00      3.00
# Playtime/Day (minute)   25.0     11.2800      1.947648      9.00     10.00
# Paying_User             25.0    245.0000    271.655266     39.00     60.00
# Gross_Rev               25.0    536.2548    502.710864    138.51    183.02
# ARPPU                   25.0      2.7712      1.042055      1.29      2.09
# ARPDAU                  25.0      0.0740      0.013229      0.05      0.07
# ...
